# %%
import numpy as npimport pickleimport json

# %%
def calc_special_case(params, verbose=True):    """    Calculate nearest special case given a set of params.        """    boltzmann = 8.6173324e-5    if (params["em_barrier_ht"] + params["em_voltage"]) > \      (params["co_barrier_ht"] + params["co_voltage"]):        psi_m = params["em_barrier_ht"]    else:        psi_m = params["co_barrier_ht"] + \          (params["co_voltage"] - params["em_voltage"])        n = np.round(psi_m / (boltzmann * params["em_temp"]))    params["em_temp"] = psi_m / (boltzmann * n)        J = (params["em_richardson"] * psi_m**2) / \      (np.exp(n) * n**2 * boltzmann**2)            # Break off the exponent, round the resulting mantissa,     # and put everything back together    if J > 0:        exponent = np.floor(np.log10(J))        J = np.round(J / 10**exponent) * 10**exponent                params["em_richardson"] = (J * np.exp(n) * n**2 * boltzmann**2) / \          psi_m**2        params["forward_current_density"] = J        if verbose:        print "n = psi_m/(boltzmann * em_temp)"        print str(n) + " = " + str(psi_m) + "/(" + \          str(boltzmann) + " * " + str(params["em_temp"]) + ")"        print "\r"        print "forward_current_density = (em_richardson * psi_m**2)/" +\          "\r  (exp(n) * n**2 * boltzmann**2)"        print str(J) + " = (" + str(params["em_richardson"]) + " * " +\          str(psi_m) + "**2)/" + \          "\r  (exp(" + str(n) + ") * " + str(n) + "**2 * " + \          str(boltzmann) + "**2)"        print "\r"        # The JSON stuff is only for pretty-printing.        #print(json.dumps(params,indent=0))                print "Emitter"        print " richardson:", params["em_richardson"]        print " barrier_ht:", params["em_barrier_ht"]        print " temp:      ", params["em_temp"]        print " voltage:   ", params["em_voltage"]        print "Collector"        print " barrier_ht:", params["co_barrier_ht"]        print " voltage:   ", params["co_voltage"]        print "\r"        print "forward_current_density:", J        print "========================================"        return params

# %%
em_richardsons = [0.01,100]em_barrier_hts = [0.5,5.0]em_temps = [200,2000]em_voltages = [-10,10]co_barrier_hts = [0.5,5.0]co_voltages = [-10,10]std = []

# %%
for em_richardson in em_richardsons:    for em_barrier_ht in em_barrier_hts:        for em_temp in em_temps:            for em_voltage in em_voltages:                for co_barrier_ht in co_barrier_hts:                    for co_voltage in co_voltages:                        params = {"em_richardson":em_richardson,                                  "em_barrier_ht":em_barrier_ht,                                  "em_temp":em_temp,                                  "em_voltage":em_voltage,                                  "co_barrier_ht":co_barrier_ht,                                  "co_voltage":co_voltage}                        params = calc_special_case(params)                        std.append(params)
# Out:
# n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-10 = (0.00982068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 1e-10========================================n = psi_m/(boltzmann * em_temp)1189.0 = 20.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (0.01 * 20.5**2)/  (exp(1189.0) * 1189.0**2 * 8.6173324e-05**2)Emitter richardson: 0.01 barrier_ht: 0.5 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 0.5 temp:       200.077918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)1451.0 = 25.0/(8.6173324e-05 * 199.94002899)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (0.01 * 25.0**2)/  (exp(1451.0) * 1451.0**2 * 8.6173324e-05**2)Emitter richardson: 0.01 barrier_ht: 0.5 temp:       199.94002899 voltage:    -10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-10 = (0.00982068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 1e-10========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-10 = (0.00982068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density:
# 1e-10========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-10 = (0.00982068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 1e-10========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)2000.0 = (0.010738945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 0.010738945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 2000.0========================================n = psi_m/(boltzmann * em_temp)119.0 = 20.5/(8.6173324e-05 * 1999.0978596)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)8e-48 = (0.00960428911769 * 20.5**2)/  (exp(119.0) * 119.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00960428911769 barrier_ht: 0.5 temp:       1999.0978596 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 8e-48========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 0.5 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)145.0 = 25.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)4e-59 = (0.00938342842027 * 25.0**2)/  (exp(145.0) * 145.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00938342842027 barrier_ht: 0.5 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 4e-59========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)2000.0 = (0.010738945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 0.010738945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 2000.0========================================
# n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)2000.0 = (0.010738945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 0.010738945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 2000.0========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)2000.0 = (0.010738945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 0.010738945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 2000.0========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 0.5 temp:       2000.77918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)1189.0 = 20.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (0.01 * 20.5**2)/  (exp(1189.0) * 1189.0**2 * 8.6173324e-05**2)Emitter richardson: 0.01 barrier_ht: 5.0 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)1451.0 = 25.0/(8.6173324e-05 * 199.94002899)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (0.01 * 25.0**2)/  (exp(1451.0) * 1451.0**2 * 8.6173324e-05**2)Emitter richardson: 0.01 barrier_ht: 5.0 temp:       199.94002899 voltage:    -10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)
# forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-124 = (0.0110146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 0.0110146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 5e-124========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)119.0 = 20.5/(8.6173324e-05 * 1999.0978596)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)8e-48 = (0.00960428911769 * 20.5**2)/  (exp(119.0) * 119.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00960428911769 barrier_ht: 5.0 temp:       1999.0978596 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 8e-48========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)145.0 = 25.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)4e-59 = (0.00938342842027 * 25.0**2)/  (exp(145.0) * 145.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00938342842027 barrier_ht: 5.0 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 4e-59========================================n = psi_m/(boltzmann * em_temp)
# 29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-08 = (0.00982068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 0.00982068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 1e-08========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-06 = (98.2068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 1e-06========================================n = psi_m/(boltzmann * em_temp)1189.0 = 20.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (100 * 20.5**2)/  (exp(1189.0) * 1189.0**2 * 8.6173324e-05**2)Emitter richardson: 100 barrier_ht: 0.5 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 0.5 temp:       200.077918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)1451.0 = 25.0/(8.6173324e-05 * 199.94002899)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (100 * 25.0**2)/  (exp(1451.0) * 1451.0**2 * 8.6173324e-05**2)Emitter richardson: 100 barrier_ht: 0.5 temp:       199.94002899 voltage:    -10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 0.0
# ========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-06 = (98.2068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 1e-06========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-06 = (98.2068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 1e-06========================================n = psi_m/(boltzmann * em_temp)29.0 = 0.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)1e-06 = (98.2068210788 * 0.5**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 1e-06========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 0.5 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)20000000.0 = (107.38945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 107.38945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 20000000.0========================================n = psi_m/(boltzmann * em_temp)119.0 = 20.5/(8.6173324e-05 * 1999.0978596)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)8e-44 = (96.0428911769 * 20.5**2)/  (exp(119.0) * 119.0**2 * 8.6173324e-05**2)Emitter richardson: 96.0428911769 barrier_ht: 0.5 temp:       1999.0978596 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 8e-44========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 0.5 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)145.0 = 25.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)4e-55 = (93.8342842027 * 25.0**2)/  (exp(145.0) * 145.0**2 * 8.6173324e-05**2)Emitter richardson: 93.8342842027 barrier_ht: 0.5 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0
#  voltage:    10forward_current_density: 4e-55========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)20000000.0 = (107.38945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 107.38945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 20000000.0========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)20000000.0 = (107.38945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 107.38945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 20000000.0========================================n = psi_m/(boltzmann * em_temp)3.0 = 0.5/(8.6173324e-05 * 1934.08654709)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)20000000.0 = (107.38945371 * 0.5**2)/  (exp(3.0) * 3.0**2 * 8.6173324e-05**2)Emitter richardson: 107.38945371 barrier_ht: 0.5 temp:       1934.08654709 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 20000000.0========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 0.5 temp:       2000.77918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)1189.0 = 20.5/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (100 * 20.5**2)/  (exp(1189.0) * 1189.0**2 * 8.6173324e-05**2)Emitter richardson: 100 barrier_ht: 5.0 temp:       200.077918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)1451.0 = 25.0/(8.6173324e-05 * 199.94002899)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0 = (100 * 25.0**2)/  (exp(1451.0) * 1451.0**2 * 8.6173324e-05**2)Emitter richardson: 100 barrier_ht: 5.0 temp:       199.94002899 voltage:    -10
# Collector barrier_ht: 5.0 voltage:    10forward_current_density: 0.0========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)290.0 = 5.0/(8.6173324e-05 * 200.077918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)5e-120 = (110.146685846 * 5.0**2)/  (exp(290.0) * 290.0**2 * 8.6173324e-05**2)Emitter richardson: 110.146685846 barrier_ht: 5.0 temp:       200.077918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 5e-120========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)119.0 = 20.5/(8.6173324e-05 * 1999.0978596)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)8e-44 = (96.0428911769 * 20.5**2)/  (exp(119.0) * 119.0**2 * 8.6173324e-05**2)Emitter richardson: 96.0428911769 barrier_ht: 5.0 temp:       1999.0978596 voltage:    -10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 8e-44========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)145.0 = 25.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)4e-55 = (93.8342842027 * 25.0**2)/  (exp(145.0) * 145.0**2 * 8.6173324e-05**2)Emitter richardson: 93.8342842027 barrier_ht: 5.0 temp:       2000.77918665 voltage:    -10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 4e-55========================================n = psi_m/(boltzmann * em_temp)
# 29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 0.5 voltage:    -10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 0.5 voltage:    10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 5.0 voltage:    -10forward_current_density: 0.0001========================================n = psi_m/(boltzmann * em_temp)29.0 = 5.0/(8.6173324e-05 * 2000.77918665)forward_current_density = (em_richardson * psi_m**2)/  (exp(n) * n**2 * boltzmann**2)0.0001 = (98.2068210788 * 5.0**2)/  (exp(29.0) * 29.0**2 * 8.6173324e-05**2)Emitter richardson: 98.2068210788 barrier_ht: 5.0 temp:       2000.77918665 voltage:    10Collector barrier_ht: 5.0 voltage:    10forward_current_density: 0.0001========================================

# %%
#print std#pickle.dump(std,open("TEC.calc_forward_current_density_STANDARD.dat","w"))
